# %%
import csv
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data=pd.read_csv("numbers.csv")
data.shape
data.head()
# Out:
#       obs  conductivity_millisiemens  conductivity_millisiemens_qc_executed  \
# 0  ('0',)                  31.426399                                      1
# 1  ('1',)                  31.426600                                      1
# 2  ('2',)                  31.426800                                      1
# 3  ('3',)                  31.426600                                      1
# 4  ('4',)                  31.426600                                      1
#
#    conductivity_millisiemens_qc_results      density  density_qc_executed  \
# 0                                     0  1039.812423                   29
# 1                                     0  1039.813072                   29
# 2                                     0  1039.812864                   29
# 3                                     0  1039.813006                   29
# 4                                     0  1039.812877                   29
#
#    density_qc_results  deployment  dpc_ctd_seawater_conductivity  \
# 0                  13           4                        3.14264
# 1                  13           4                        3.14266
# 2                  13           4                        3.14268
# 3                  13           4                        3.14266
# 4                  13           4                        3.14266
#
#    dpc_ctd_seawater_conductivity_qc_executed  ...  preferred_timestamp  \
# 0                                         29  ...   internal_timestamp
# 1                                         29  ...   internal_timestamp
# 2                                         29  ...   internal_timestamp
# 3                                         29  ...   internal_timestamp
# 4                                         29  ...   internal_timestamp
#
#       pressure  pressure_qc_executed  pressure_qc_results  \
# 0  2641.899902                    29                   29
# 1  2641.939941                    29                   29
# 2  2641.889893                    29                   29
# 3  2641.899902                    29                   29
# 4  2641.939941                    29                   29
#
#    raw_time_microseconds  raw_time_seconds    temp  temp_qc_executed  \
# 0                 971300        1577923232  1.8156                29
# 1                 279517        1577923235  1.8153                29
# 2                 541065        1577923236  1.8155                29
# 3                 490138        1577923237  1.8152                29
# 4                 385474        1577923238  1.8155                29
#
#    temp_qc_results          time
# 0               29  3.786912e+09
# 1               29  3.786912e+09
# 2               29  3.786912e+09
# 3               29  3.786912e+09
# 4               29  3.786912e+09
#
# [5 rows x 30 columns]

# %%
x=data.pressure
y=data.temp

# %%
plt.plot(x,y)
plt.ylabel('temperature [*C]')
plt.xlabel('pressure [dbar]')
plt.title('Pressure vs Temperature')
# Out:
# Text(0.5, 1.0, 'Pressure vs Temperature')
